# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
gapminder = pd.read_csv("Datasets\\gapminder.csv")

gapminder
# Out:
#      Unnamed: 0             country  year  population      cont  life_exp  \
# 0            11         Afghanistan  2007  31889923.0      Asia    43.828
# 1            23             Albania  2007   3600523.0    Europe    76.423
# 2            35             Algeria  2007  33333216.0    Africa    72.301
# 3            47              Angola  2007  12420476.0    Africa    42.731
# 4            59           Argentina  2007  40301927.0  Americas    75.320
# ..          ...                 ...   ...         ...       ...       ...
# 137        1655             Vietnam  2007  85262356.0      Asia    74.249
# 138        1667  West Bank and Gaza  2007   4018332.0      Asia    73.422
# 139        1679         Yemen, Rep.  2007  22211743.0      Asia    62.698
# 140        1691              Zambia  2007  11746035.0    Africa    42.384
# 141        1703            Zimbabwe  2007  12311143.0    Africa    43.487
#
#           gdp_cap
# 0      974.580338
# 1     5937.029526
# 2     6223.367465
# ...

# %%
# Create a scatter plot with GDP per capita on the x-axis and life expectancy on the y-axis
plt.scatter(gapminder["gdp_cap"], gapminder["life_exp"])

# Set the scale of the x-axis to logarithmic
plt.xscale('log')

# Label the x-axis and y-axis
plt.xlabel("GDP per Capita [in USD]")
plt.ylabel("Life Expectancy [in years]")

# Set a title for the plot
plt.title("World Development in 2007")

# Display the plot
plt.show()

# %%
# Create a scatter plot with GDP per capita on the x-axis and life expectancy on the y-axis
plt.scatter(gapminder["gdp_cap"], gapminder["life_exp"])

# Set the scale of the x-axis to logarithmic
plt.xscale('log')

# Label the x-axis and y-axis
plt.xlabel("GDP per Capita [in USD]")
plt.ylabel("Life Expectancy [in years]")

# Set a title for the plot
plt.title("World Development in 2007")

# Define the ticks
tick_val = [1000, 10000, 100000]
tick_lab = ['1k', '10k', '100k']

# Adapt the ticks on the x-axis
plt.xticks(tick_val, tick_lab)

# Display the plot
plt.show()

# %%
# Import numpy as np
import numpy as np

# Store pop as a numpy array: np_pop
np_pop = np.array(gapminder["population"])

# Double np_pop
np_pop = (np_pop * 2) / 1000000

# Update: set s argument to np_pop
plt.scatter(gapminder["gdp_cap"], gapminder["life_exp"], s=np_pop)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])

# Display the plot
plt.show()

# %%
# Define a dictionary mapping continents to colors
continent_colors = {
    'Asia': 'red',
    'Europe': 'green',
    'Africa': 'blue',
    'Americas': 'yellow',
    'Oceania': 'black'
}

col = gapminder['cont'].map(continent_colors)

# Store pop as a numpy array: np_pop
np_pop = np.array(gapminder["population"])

# Double np_pop
np_pop = (np_pop * 2) / 1000000

# Update: set s argument to np_pop
plt.scatter(gapminder["gdp_cap"], gapminder["life_exp"], s=np_pop, c=col, alpha=0.8)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])

# Display the plot
plt.show()

# %%
plt.hist(gapminder["life_exp"], bins=15, edgecolor='white') # edgecolor for separating the bars
plt.show()
